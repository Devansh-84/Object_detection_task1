# %% [markdown]
# <a href="https://colab.research.google.com/github/Devansh-84/Object_detection_task1/blob/main/IMPROVE_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import yfinance as yf
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

# %%
# Fetch data for a stock (e.g., Apple Inc. - AAPL) from Yahoo Finance
ticker_symbol = 'RELIANCE.NS'
stock_data = yf.download(ticker_symbol, start='2010-01-01', end='2024-01-28')
stock_data.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open      Volume
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS RELIANCE.NS
# Date
# 2024-01-18  1358.695801  1361.725216  1342.108824  1342.257834    10279438
# 2024-01-19  1358.199097  1366.691304  1349.806310  1366.691304    10422704
# 2024-01-23  1319.587158  1362.470128  1313.603014  1362.470128    20055420
# 2024-01-24  1334.783691  1340.370638  1314.968702  1326.192184    21919128
# 2024-01-25  1343.921387  1354.921537  1326.167311  1333.864882    11808872

# %%
# Preprocess the data
data = stock_data['Close'].values.reshape(-1, 1)  # Convert to 2D array for scaling
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# %%
# Create the training and testing datasets
train_data = scaled_data[:int(len(scaled_data) * 0.8)]
test_data = scaled_data[int(len(scaled_data) * 0.8):]

def create_dataset(dataset, time_step=1):
    X, y = [], []
    for i in range(len(dataset) - time_step - 1):
        X.append(dataset[i:(i + time_step), 0])
        y.append(dataset[i + time_step, 0])
    return np.array(X), np.array(y)

time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
# Reshape input to be [samples, time steps, features] for LSTM
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from keras.regularizers import l2
from keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping

# Define the model with increased complexity and regularization
model = Sequential()
model.add(LSTM(units=128, return_sequences=True, input_shape=(X_train.shape[1], 1), kernel_regularizer=l2(0.001)))
model.add(Dropout(0.3))
model.add(LSTM(units=64, return_sequences=True, kernel_regularizer=l2(0.001)))
model.add(Dropout(0.3))
model.add(LSTM(units=32, kernel_regularizer=l2(0.001)))
model.add(Dropout(0.3))
model.add(Dense(units=1))


# Compile the model with RMSprop optimizer and adjusted learning rate
model.compile(loss='mse', optimizer=RMSprop(learning_rate=0.0005), metrics=['mean_absolute_error'])


# Add early stopping to prevent overfitting
#early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_6 (LSTM)                        │ (None, 100, 128)            │          66,560 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 100, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_7 (LSTM)                        │ (None, 100, 64)             │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 100, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_8 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 128,417 (501.63 KB)
#  Trainable params: 128,417 (501.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model with increased epochs and batch size
history = model.fit(X_train, y_train, epochs=80, batch_size=64, validation_data=(X_test, y_test))
# Out:
# Epoch 1/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 26s 512ms/step - loss: 0.2621 - mean_absolute_error: 0.0644 - val_loss: 0.2210 - val_mean_absolute_error: 0.0944
# Epoch 2/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 36s 392ms/step - loss: 0.2017 - mean_absolute_error: 0.0274 - val_loss: 0.1826 - val_mean_absolute_error: 0.1097
# Epoch 3/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - loss: 0.1622 - mean_absolute_error: 0.0274 - val_loss: 0.1425 - val_mean_absolute_error: 0.0773
# Epoch 4/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 396ms/step - loss: 0.1294 - mean_absolute_error: 0.0245 - val_loss: 0.1089 - val_mean_absolute_error: 0.0321
# Epoch 5/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 397ms/step - loss: 0.1032 - mean_absolute_error: 0.0260 - val_loss: 0.0878 - val_mean_absolute_error: 0.0429
# Epoch 6/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 394ms/step - loss: 0.0821 - mean_absolute_error: 0.0249 - val_loss: 0.0705 - val_mean_absolute_error: 0.0480
# Epoch 7/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 396ms/step - loss: 0.0650 - mean_absolute_error: 0.0237 - val_loss: 0.0579 - val_mean_absolute_error: 0.0606
# Epoch 8/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 394ms/step - loss: 0.0517 - mean_absolute_error: 0.0258 - val_loss: 0.0517 - val_mean_absolute_error: 0.0923
# Epoch 9/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 388ms/step - loss: 0.0410 - mean_absolute_error: 0.0252 - val_loss: 0.0351 - val_mean_absolute_error: 0.0394
# Epoch 10/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 17s 395ms/step - loss: 0.0325 - mean_absolute_error: 0.0243 - val_loss: 0.0279 - val_mean_absolute_error: 0.0372
# Epoch 11/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 429ms/step - loss: 0.0258 - mean_absolute_error: 0.0238 - val_loss: 0.0436 - val_mean_absolute_error: 0.1473
# Epoch 12/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 19s 396ms/step - loss: 0.0206 - mean_absolute_error: 0.0233 - val_loss: 0.0177 - val_mean_absolute_error: 0.0337
# Epoch 13/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 401ms/step - loss: 0.0166 - mean_absolute_error: 0.0234 - val_loss: 0.0176 - val_mean_absolute_error: 0.0597
# Epoch 14/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 396ms/step - loss: 0.0136 - mean_absolute_error: 0.0242 - val_loss: 0.0175 - val_mean_absolute_error: 0.0758
# Epoch 15/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 399ms/step - loss: 0.0110 - mean_absolute_error: 0.0227 - val_loss: 0.0110 - val_mean_absolute_error: 0.0444
# Epoch 16/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 397ms/step - loss: 0.0090 - mean_absolute_error: 0.0240 - val_loss: 0.0232 - val_mean_absolute_error: 0.1230
# Epoch 17/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 391ms/step - loss: 0.0078 - mean_absolute_error: 0.0240 - val_loss: 0.0070 - val_mean_absolute_error: 0.0354
# Epoch 18/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 18s 434ms/step - loss: 0.0064 - mean_absolute_error: 0.0249 - val_loss: 0.0067 - val_mean_absolute_error: 0.0403
# Epoch 19/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 19s 397ms/step - loss: 0.0057 - mean_absolute_error: 0.0254 - val_loss: 0.0078 - val_mean_absolute_error: 0.0541
# Epoch 20/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 399ms/step - loss: 0.0046 - mean_absolute_error: 0.0231 - val_loss: 0.0047 - val_mean_absolute_error: 0.0352
# Epoch 21/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 19s 438ms/step - loss: 0.0044 - mean_absolute_error: 0.0255 - val_loss: 0.0090 - val_mean_absolute_error: 0.0700
# Epoch 22/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 18s 386ms/step - loss: 0.0043 - mean_absolute_error: 0.0255 - val_loss: 0.0102 - val_mean_absolute_error: 0.0801
# Epoch 23/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 16s 383ms/step - loss: 0.0035 - mean_absolute_error: 0.0239 - val_loss: 0.0075 - val_mean_absolute_error: 0.0642
# Epoch 24/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 392ms/step - loss: 0.0033 - mean_absolute_error: 0.0244 - val_loss: 0.0052 - val_mean_absolute_error: 0.0490
# Epoch 25/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 16s 391ms/step - loss: 0.0030 - mean_absolute_error: 0.0253 - val_loss: 0.0085 - val_mean_absolute_error: 0.0735
# Epoch 26/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 383ms/step - loss: 0.0028 - mean_absolute_error: 0.0254 - val_loss: 0.0076 - val_mean_absolute_error: 0.0683
# Epoch 27/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 394ms/step - loss: 0.0026 - mean_absolute_error: 0.0250 - val_loss: 0.0031 - val_mean_absolute_error: 0.0362
# Epoch 28/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 17s 403ms/step - loss: 0.0025 - mean_absolute_error: 0.0254 - val_loss: 0.0117 - val_mean_absolute_error: 0.0942
# Epoch 29/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 405ms/step - loss: 0.0025 - mean_absolute_error: 0.0260 - val_loss: 0.0034 - val_mean_absolute_error: 0.0399
# Epoch 30/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 389ms/step - loss: 0.0022 - mean_absolute_error: 0.0242 - val_loss: 0.0088 - val_mean_absolute_error: 0.0782
# Epoch 31/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 16s 393ms/step - loss: 0.0022 - mean_absolute_error: 0.0249 - val_loss: 0.0075 - val_mean_absolute_error: 0.0705
# Epoch 32/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 395ms/step - loss: 0.0023 - mean_absolute_error: 0.0246 - val_loss: 0.0033 - val_mean_absolute_error: 0.0411
# Epoch 33/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - loss: 0.0023 - mean_absolute_error: 0.0251 - val_loss: 0.0067 - val_mean_absolute_error: 0.0656
# Epoch 34/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 396ms/step - loss: 0.0021 - mean_absolute_error: 0.0245 - val_loss: 0.0125 - val_mean_absolute_error: 0.0999
# Epoch 35/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 394ms/step - loss: 0.0023 - mean_absolute_error: 0.0256 - val_loss: 0.0075 - val_mean_absolute_error: 0.0714
# Epoch 36/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 396ms/step - loss: 0.0021 - mean_absolute_error: 0.0238 - val_loss: 0.0072 - val_mean_absolute_error: 0.0691
# Epoch 37/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 16s 384ms/step - loss: 0.0021 - mean_absolute_error: 0.0262 - val_loss: 0.0026 - val_mean_absolute_error: 0.0360
# Epoch 38/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 413ms/step - loss: 0.0023 - mean_absolute_error: 0.0271 - val_loss: 0.0026 - val_mean_absolute_error: 0.0361
# Epoch 39/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 19s 388ms/step - loss: 0.0020 - mean_absolute_error: 0.0230 - val_loss: 0.0087 - val_mean_absolute_error: 0.0790
# Epoch 40/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 405ms/step - loss: 0.0023 - mean_absolute_error: 0.0256 - val_loss: 0.0042 - val_mean_absolute_error: 0.0479
# Epoch 41/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - loss: 0.0021 - mean_absolute_error: 0.0243 - val_loss: 0.0104 - val_mean_absolute_error: 0.0891
# Epoch 42/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 404ms/step - loss: 0.0020 - mean_absolute_error: 0.0254 - val_loss: 0.0026 - val_mean_absolute_error: 0.0361
# Epoch 43/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 389ms/step - loss: 0.0020 - mean_absolute_error: 0.0246 - val_loss: 0.0033 - val_mean_absolute_error: 0.0424
# Epoch 44/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 435ms/step - loss: 0.0020 - mean_absolute_error: 0.0234 - val_loss: 0.0070 - val_mean_absolute_error: 0.0689
# Epoch 45/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 19s 393ms/step - loss: 0.0020 - mean_absolute_error: 0.0237 - val_loss: 0.0028 - val_mean_absolute_error: 0.0387
# Epoch 46/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 440ms/step - loss: 0.0020 - mean_absolute_error: 0.0247 - val_loss: 0.0096 - val_mean_absolute_error: 0.0850
# Epoch 47/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 18s 391ms/step - loss: 0.0022 - mean_absolute_error: 0.0267 - val_loss: 0.0029 - val_mean_absolute_error: 0.0388
# Epoch 48/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 437ms/step - loss: 0.0020 - mean_absolute_error: 0.0234 - val_loss: 0.0261 - val_mean_absolute_error: 0.1540
# Epoch 49/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 16s 384ms/step - loss: 0.0021 - mean_absolute_error: 0.0260 - val_loss: 0.0211 - val_mean_absolute_error: 0.1369
# Epoch 50/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 16s 384ms/step - loss: 0.0020 - mean_absolute_error: 0.0258 - val_loss: 0.0085 - val_mean_absolute_error: 0.0782
# Epoch 51/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 406ms/step - loss: 0.0020 - mean_absolute_error: 0.0237 - val_loss: 0.0082 - val_mean_absolute_error: 0.0763
# Epoch 52/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - loss: 0.0022 - mean_absolute_error: 0.0270 - val_loss: 0.0253 - val_mean_absolute_error: 0.1515
# Epoch 53/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 426ms/step - loss: 0.0021 - mean_absolute_error: 0.0248 - val_loss: 0.0112 - val_mean_absolute_error: 0.0940
# Epoch 54/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 19s 391ms/step - loss: 0.0020 - mean_absolute_error: 0.0256 - val_loss: 0.0047 - val_mean_absolute_error: 0.0529
# Epoch 55/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 398ms/step - loss: 0.0020 - mean_absolute_error: 0.0251 - val_loss: 0.0025 - val_mean_absolute_error: 0.0364
# Epoch 56/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 394ms/step - loss: 0.0021 - mean_absolute_error: 0.0254 - val_loss: 0.0029 - val_mean_absolute_error: 0.0390
# Epoch 57/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 428ms/step - loss: 0.0019 - mean_absolute_error: 0.0236 - val_loss: 0.0077 - val_mean_absolute_error: 0.0739
# Epoch 58/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 16s 383ms/step - loss: 0.0019 - mean_absolute_error: 0.0245 - val_loss: 0.0068 - val_mean_absolute_error: 0.0677
# Epoch 59/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 387ms/step - loss: 0.0020 - mean_absolute_error: 0.0238 - val_loss: 0.0124 - val_mean_absolute_error: 0.1000
# Epoch 60/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 16s 386ms/step - loss: 0.0021 - mean_absolute_error: 0.0254 - val_loss: 0.0027 - val_mean_absolute_error: 0.0378
# Epoch 61/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 390ms/step - loss: 0.0018 - mean_absolute_error: 0.0228 - val_loss: 0.0064 - val_mean_absolute_error: 0.0648
# Epoch 62/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 422ms/step - loss: 0.0022 - mean_absolute_error: 0.0267 - val_loss: 0.0094 - val_mean_absolute_error: 0.0845
# Epoch 63/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 19s 386ms/step - loss: 0.0019 - mean_absolute_error: 0.0252 - val_loss: 0.0024 - val_mean_absolute_error: 0.0355
# Epoch 64/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 408ms/step - loss: 0.0019 - mean_absolute_error: 0.0232 - val_loss: 0.0045 - val_mean_absolute_error: 0.0512
# Epoch 65/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 385ms/step - loss: 0.0019 - mean_absolute_error: 0.0240 - val_loss: 0.0041 - val_mean_absolute_error: 0.0483
# Epoch 66/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 397ms/step - loss: 0.0020 - mean_absolute_error: 0.0238 - val_loss: 0.0177 - val_mean_absolute_error: 0.1243
# Epoch 67/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 391ms/step - loss: 0.0019 - mean_absolute_error: 0.0241 - val_loss: 0.0056 - val_mean_absolute_error: 0.0595
# Epoch 68/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 417ms/step - loss: 0.0018 - mean_absolute_error: 0.0233 - val_loss: 0.0028 - val_mean_absolute_error: 0.0388
# Epoch 69/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 19s 384ms/step - loss: 0.0022 - mean_absolute_error: 0.0268 - val_loss: 0.0213 - val_mean_absolute_error: 0.1381
# Epoch 70/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 396ms/step - loss: 0.0018 - mean_absolute_error: 0.0245 - val_loss: 0.0038 - val_mean_absolute_error: 0.0470
# Epoch 71/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 388ms/step - loss: 0.0019 - mean_absolute_error: 0.0244 - val_loss: 0.0088 - val_mean_absolute_error: 0.0810
# Epoch 72/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 409ms/step - loss: 0.0019 - mean_absolute_error: 0.0239 - val_loss: 0.0179 - val_mean_absolute_error: 0.1249
# Epoch 73/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 17s 409ms/step - loss: 0.0019 - mean_absolute_error: 0.0246 - val_loss: 0.0064 - val_mean_absolute_error: 0.0653
# Epoch 74/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 16s 388ms/step - loss: 0.0019 - mean_absolute_error: 0.0254 - val_loss: 0.0122 - val_mean_absolute_error: 0.0997
# Epoch 75/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 389ms/step - loss: 0.0019 - mean_absolute_error: 0.0254 - val_loss: 0.0091 - val_mean_absolute_error: 0.0830
# Epoch 76/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 395ms/step - loss: 0.0018 - mean_absolute_error: 0.0241 - val_loss: 0.0140 - val_mean_absolute_error: 0.1086
# Epoch 77/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 430ms/step - loss: 0.0019 - mean_absolute_error: 0.0238 - val_loss: 0.0027 - val_mean_absolute_error: 0.0377
# Epoch 78/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 17s 395ms/step - loss: 0.0019 - mean_absolute_error: 0.0256 - val_loss: 0.0027 - val_mean_absolute_error: 0.0377
# Epoch 79/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 394ms/step - loss: 0.0017 - mean_absolute_error: 0.0232 - val_loss: 0.0237 - val_mean_absolute_error: 0.1465
# Epoch 80/80
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 392ms/step - loss: 0.0019 - mean_absolute_error: 0.0237 - val_loss: 0.0084 - val_mean_absolute_error: 0.0786

# %%
# Save the model
model.save('stock_prediction_model_9.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Evaluate the model with additional metrics
loss, mae = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}, Test MAE: {mae}')

# Visualize training history
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 188ms/step - loss: 0.0088 - mean_absolute_error: 0.0796
# Test Loss: 0.00842692144215107, Test MAE: 0.07861035317182541

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 8s 89ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step

# %%
# Ensure both y_train and train_predict have compatible shapes
print(f"y_train shape: {y_train.shape}")
print(f"train_predict shape: {train_predict.shape}")
print(f"y_test shape: {y_test.shape}")
print(f"test_predict shape: {test_predict.shape}")
# Out:
# y_train shape: (2676,)
# train_predict shape: (2676, 1)
# y_test shape: (594,)
# test_predict shape: (594, 1)

# %%
# Inverse transform the predictions to get actual stock prices
train_predict = scaler.inverse_transform(train_predict)
y_train = scaler.inverse_transform([y_train])
test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform([y_test])

# %%
# Model evaluation
from sklearn.metrics import mean_squared_error
train_rmse = np.sqrt(mean_squared_error(y_train[0], train_predict[:, 0]))
test_rmse = np.sqrt(mean_squared_error(y_test[0], test_predict[:, 0]))
print(f'Train RMSE: {train_rmse}')
print(f'Test RMSE: {test_rmse}')
# Out:
# Train RMSE: 37.62220901139403
# Test RMSE: 110.92484076488162

# %%
# Visualize the results
plt.style.use('fivethirtyeight')
# Plot the data
plt.figure(figsize=(20, 10))

# Plot training predictions and actuals
plt.plot(stock_data.index[time_step+1:time_step+len(train_predict)+1], train_predict, label='Train Predictions')
plt.plot(stock_data.index[time_step+1:time_step+len(train_predict)+1], y_train[0], label='Train Actuals')

# Plot testing predictions and actuals
test_index = stock_data.index[time_step+len(train_predict)+1:time_step+len(train_predict)+1+len(test_predict)]
plt.plot(test_index, test_predict, label='Test Predictions')
plt.plot(test_index[:len(test_predict)], y_test[0][:len(test_predict)], label='Test Actuals')

plt.legend()
plt.show()

# %%
# Extend predictions for the next 10 days
future_time_steps = 10
future_predictions = []

# %%
# Use the last sequence from the testing data to start predicting the future
last_sequence = X_test[-1]

for i in range(future_time_steps):
    # Predict the next price
    next_prediction = model.predict(np.array([last_sequence]))[0, 0]

    # Append the prediction to the list of future predictions
    future_predictions.append(next_prediction)

    # Update the last sequence with the new prediction
    last_sequence = np.roll(last_sequence, -1)
    last_sequence[-1] = next_prediction
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step

# %%
# Inverse transform the future predictions to get the actual stock prices
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))

# %%
# Get the last date in the original dataset
last_date = stock_data.index[-1]

# Generate dates for the next 10 days
next_dates = pd.date_range(start=last_date, periods=future_time_steps + 1)[1:]  # Skip the last date

# %%
 #Print the predicted prices for the next 10 days along with dates
print("Predicted prices for the next 10 days:")
for date, prediction in zip(next_dates, future_predictions):
    print(f"{date.strftime('%Y-%m-%d')}: {prediction[0]:.2f}")
# Out:
# Predicted prices for the next 10 days:
# 2024-01-26: 1168.75
# 2024-01-27: 1172.17
# 2024-01-28: 1175.08
# 2024-01-29: 1177.30
# 2024-01-30: 1178.67
# 2024-01-31: 1179.10
# 2024-02-01: 1178.57
# 2024-02-02: 1177.06
# 2024-02-03: 1174.63
# 2024-02-04: 1171.34

# %%
# Extend predictions for the next 100 days
future_time_steps = 100
future_predictions = []

# Use the last sequence from the testing data to start predicting the future
last_sequence = X_test[-1]

for i in range(future_time_steps):
    # Predict the next price
    next_prediction = model.predict(np.array([last_sequence]))[0, 0]

    # Append the prediction to the list of future predictions
    future_predictions.append(next_prediction)

    # Update the last sequence with the new prediction
    last_sequence = np.roll(last_sequence, -1)
    last_sequence[-1] = next_prediction

# Inverse transform the future predictions to get the actual stock prices
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))

# Generate dates for the next 100 days
next_dates = pd.date_range(start=last_date, periods=future_time_steps + 1)[1:]  # Skip the last date

# Plot the original and predicted prices for the next 100 days
plt.figure(figsize=(16, 8))
plt.plot(stock_data.index[-len(y_test[0]):], y_test[0], label='Original Prices')
plt.plot(next_dates, future_predictions, label='Predicted Prices')
plt.title('Original vs. Predicted Prices for the Next 100 Days')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step

# %%
print("Predicted prices for the next 100 days:")
for date, prediction in zip(next_dates, future_predictions):
    print(f"{date.strftime('%Y-%m-%d')}: {prediction[0]:.2f}")
# Out:
# Predicted prices for the next 100 days:
# 2024-01-26: 1168.75
# 2024-01-27: 1172.17
# 2024-01-28: 1175.08
# 2024-01-29: 1177.30
# 2024-01-30: 1178.67
# 2024-01-31: 1179.10
# 2024-02-01: 1178.57
# 2024-02-02: 1177.06
# 2024-02-03: 1174.63
# 2024-02-04: 1171.34
# 2024-02-05: 1167.28
# 2024-02-06: 1162.55
# 2024-02-07: 1157.27
# 2024-02-08: 1151.54
# 2024-02-09: 1145.47
# 2024-02-10: 1139.16
# 2024-02-11: 1132.68
# 2024-02-12: 1126.13
# 2024-02-13: 1119.56
# 2024-02-14: 1113.02
# 2024-02-15: 1106.56
# 2024-02-16: 1100.21
# 2024-02-17: 1093.98
# 2024-02-18: 1087.89
# 2024-02-19: 1081.94
# 2024-02-20: 1076.14
# 2024-02-21: 1070.48
# 2024-02-22: 1064.95
# 2024-02-23: 1059.56
# 2024-02-24: 1054.28
# 2024-02-25: 1049.11
# 2024-02-26: 1044.03
# 2024-02-27: 1039.05
# 2024-02-28: 1034.15
# 2024-02-29: 1029.33
# 2024-03-01: 1024.58
# 2024-03-02: 1019.89
# 2024-03-03: 1015.26
# 2024-03-04: 1010.69
# 2024-03-05: 1006.17
# 2024-03-06: 1001.71
# 2024-03-07: 997.29
# 2024-03-08: 992.93
# 2024-03-09: 988.61
# 2024-03-10: 984.35
# 2024-03-11: 980.13
# 2024-03-12: 975.97
# 2024-03-13: 971.85
# 2024-03-14: 967.77
# 2024-03-15: 963.75
# 2024-03-16: 959.77
# 2024-03-17: 955.84
# 2024-03-18: 951.95
# 2024-03-19: 948.10
# 2024-03-20: 944.30
# 2024-03-21: 940.54
# 2024-03-22: 936.83
# 2024-03-23: 933.15
# 2024-03-24: 929.51
# 2024-03-25: 925.92
# 2024-03-26: 922.36
# 2024-03-27: 918.84
# 2024-03-28: 915.35
# 2024-03-29: 911.90
# 2024-03-30: 908.49
# 2024-03-31: 905.11
# 2024-04-01: 901.76
# 2024-04-02: 898.44
# 2024-04-03: 895.16
# 2024-04-04: 891.91
# 2024-04-05: 888.69
# 2024-04-06: 885.50
# 2024-04-07: 882.33
# 2024-04-08: 879.20
# 2024-04-09: 876.10
# 2024-04-10: 873.02
# 2024-04-11: 869.97
# 2024-04-12: 866.95
# 2024-04-13: 863.95
# 2024-04-14: 860.98
# 2024-04-15: 858.03
# 2024-04-16: 855.11
# 2024-04-17: 852.22
# 2024-04-18: 849.35
# 2024-04-19: 846.50
# 2024-04-20: 843.67
# 2024-04-21: 840.87
# 2024-04-22: 838.09
# 2024-04-23: 835.33
# 2024-04-24: 832.60
# 2024-04-25: 829.88
# 2024-04-26: 827.19
# 2024-04-27: 824.51
# 2024-04-28: 821.86
# 2024-04-29: 819.23
# 2024-04-30: 816.61
# 2024-05-01: 814.02
# 2024-05-02: 811.44
# 2024-05-03: 808.88
# 2024-05-04: 806.35
